# %% [markdown]
# # Regressão Logística - Predição de Clicks em Anuncios
#
# Para este estudo trabalharemos com um conjunto de dados forjado, usaremos conseitos de Machine Learning para prever se um usuario clicará ou não em uma determinado anuncio baseando-se nos atributos desse usuario.
#
# Esse conjunto de dados contem os seguintes campos:
#
# - 'Daily Time Spent on Site': tempo no site em minutos.
# - 'Age': idade do consumidor.
# - 'Area Income': Média da renda do consumidor na região.
# - 'Daily Internet Usage': Média em minutos por dia que o consumidor está na internet.
# - 'Linha do tópico do anúncio': Título do anúncio.
# - 'City': Cidade do consumidor.
# - 'Male': Se o consumidor era ou não masculino.
# - 'Country': País do consumidor.
# - 'Timestamp': hora em que o consumidor clicou no anúncio ou janela fechada.
# - 'Clicked on Ad'': 0 ou 1 indicam se clicou ou não no anúncio.
#
# Esses dados estão armazenados no arquivo advertising.csv

# %% [markdown]
# ## Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Acessando os Dados

# %%
ad_data = pd.read_csv('advertising.csv')

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Para uma análise usaremos a biblioteca Seaborn para criar os graficos

# %%
sns.set_style('whitegrid')
ad_data['Age'].hist(bins=30)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
sns.jointplot(x='Age',y='Area Income',data=ad_data)

# %%
sns.jointplot(x='Age',y='Daily Time Spent on Site',data=ad_data,color='red',hue='Clicked on Ad',kind='kde')

# %%
sns.jointplot(x='Daily Time Spent on Site',y='Daily Internet Usage',data=ad_data,color='green',hue='Clicked on Ad', palette='rocket')

# %%
sns.pairplot(ad_data,hue='Clicked on Ad',palette='Set2') #bwr

# %% [markdown]
# ## Regressão Logística
# Agora é hora de quebrar nossos dados em treino e teste e fitar nosso modelo.

# %%
from sklearn.model_selection import train_test_split

# %%
X = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income','Daily Internet Usage', 'Male']]
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Treinamento do Modelo

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predição

# %%
predictions = logmodel.predict(X_test)

# %% [markdown]
# ## Teste

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       162
#            1       0.96      0.85      0.90       168
#
#     accuracy                           0.91       330
#    macro avg       0.91      0.91      0.91       330
# weighted avg       0.91      0.91      0.91       330

# %% [markdown]
# ## Deploy do modelo

# %%
# !pip install m2cgen

# %%
import m2cgen as m2c

# %%
model_to_python = m2c.export_to_python(logmodel)

# %%
print(model_to_python)
# Out:
# def score(input):
#     return 0.00542383227091849 + input[0] * -0.054179555402539874 + input[1] * 0.26035240770489054 + input[2] * -0.000017133480235940475 + input[3] * -0.02671175536741545 + input[4] * 0.0023112923168977727

# %%
def score(input):
    return 0.00542383227091849 + input[0] * -0.054179555402539874 + input[1] * 0.26035240770489054 + input[2] * -0.000017133480235940475 + input[3] * -0.02671175536741545 + input[4] * 0.0023112923168977727

# %%
input = [66.88, 35.0, 62790.96, 119.47, 1.0]

pred = score(input) 
print("prediction result: {}".format(int(pred)))
# Out:
# prediction result: 1
